# %%
# %matplotlib inline
from pylab import *
from sci378 import *
# Out:
# Version:  0.0.30

# %%
# y=a*sin^2(θ)

# %%
S=Storage()

θ=0
dθ=0.1
a=1

while θ<180:

    y=a*sin(radians(θ))**2
    S+=θ,y

    θ=θ+dθ

θ,y=S.arrays()
plot(θ,y)

# %%
for a in [1,2,3,4]:
    S=Storage()
    
    θ=0
    dθ=0.1
    #a=1
    
    while θ<180:
    
        y=a*sin(radians(θ))**2
        S+=θ,y
    
        θ=θ+dθ
    
    θ,y=S.arrays()
    plot(θ,y)X

# %%
for a in [1,2,3,4]:
    θ=linspace(0,180,400)
    y=a*sin(radians(θ))**2
    plot(θ,y)
