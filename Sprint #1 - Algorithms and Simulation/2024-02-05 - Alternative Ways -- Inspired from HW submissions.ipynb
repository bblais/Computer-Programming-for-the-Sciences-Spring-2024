# %%
# %matplotlib inline
from pylab import *
from sci378 import *
# Out:
# Version:  0.0.30

# %%
def f(x):
    # f(x)=4x^3-2x^2  in math
    return 4*x**3-2*x**2

# %% [markdown]
# ## derivative using the `diff` function

# %%
x=linspace(-2,2,100)
y=f(x)
plot(x,y)

# %%
x
# Out:
# array([-2.        , -1.95959596, -1.91919192, -1.87878788, -1.83838384,
#        -1.7979798 , -1.75757576, -1.71717172, -1.67676768, -1.63636364,
#        -1.5959596 , -1.55555556, -1.51515152, -1.47474747, -1.43434343,
#        -1.39393939, -1.35353535, -1.31313131, -1.27272727, -1.23232323,
#        -1.19191919, -1.15151515, -1.11111111, -1.07070707, -1.03030303,
#        -0.98989899, -0.94949495, -0.90909091, -0.86868687, -0.82828283,
#        -0.78787879, -0.74747475, -0.70707071, -0.66666667, -0.62626263,
#        -0.58585859, -0.54545455, -0.50505051, -0.46464646, -0.42424242,
#        -0.38383838, -0.34343434, -0.3030303 , -0.26262626, -0.22222222,
#        -0.18181818, -0.14141414, -0.1010101 , -0.06060606, -0.02020202,
#         0.02020202,  0.06060606,  0.1010101 ,  0.14141414,  0.18181818,
#         0.22222222,  0.26262626,  0.3030303 ,  0.34343434,  0.38383838,
#         0.42424242,  0.46464646,  0.50505051,  0.54545455,  0.58585859,
#         0.62626263,  0.66666667,  0.70707071,  0.74747475,  0.78787879,
#         0.82828283,  0.86868687,  0.90909091,  0.94949495,  0.98989899,
#         1.03030303,  1.07070707,  1.11111111,  1.15151515,  1.19191919,
#         1.23232323,  1.27272727,  1.31313131,  1.35353535,  1.39393939,
#         1.43434343,  1.47474747,  1.51515152,  1.55555556,  1.5959596 ,
#         1.63636364,  1.67676768,  1.71717172,  1.75757576,  1.7979798 ,
#         1.83838384,  1.87878788,  1.91919192,  1.95959596,  2.        ])

# %%
y
# Out:
# array([-4.00000000e+01, -3.77795545e+01, -3.56424154e+01, -3.35869995e+01,
#        -3.16117238e+01, -2.97150054e+01, -2.78952612e+01, -2.61509081e+01,
#        -2.44803633e+01, -2.28820436e+01, -2.13543660e+01, -1.98957476e+01,
#        -1.85046053e+01, -1.71793561e+01, -1.59184169e+01, -1.47202048e+01,
#        -1.35831367e+01, -1.25056297e+01, -1.14861007e+01, -1.05229666e+01,
#        -9.61464456e+00, -8.75955144e+00, -7.95610425e+00, -7.20271999e+00,
#        -6.49781562e+00, -5.83980814e+00, -5.22711453e+00, -4.65815177e+00,
#        -4.13133684e+00, -3.64508672e+00, -3.19781840e+00, -2.78794887e+00,
#        -2.41389510e+00, -2.07407407e+00, -1.76690278e+00, -1.49079820e+00,
#        -1.24417731e+00, -1.02545710e+00, -8.33054553e-01, -6.65386649e-01,
#        -5.20870371e-01, -3.97922702e-01, -2.94960626e-01, -2.10401124e-01,
#        -1.42661180e-01, -9.01577761e-02, -5.13078958e-02, -2.45285216e-02,
#        -8.23663634e-03, -8.49222765e-04, -7.83263716e-04, -6.45574199e-03,
#        -1.62836404e-02, -2.86839418e-02, -4.20736289e-02, -5.48696845e-02,
#        -6.54890915e-02, -7.23488327e-02, -7.38658908e-02, -6.84572487e-02,
#        -5.45398893e-02, -3.05307951e-02,  5.15305076e-03,  5.40946657e-02,
#         1.17877067e-01,  1.98083271e-01,  2.96296296e-01,  4.14099159e-01,
#         5.53074877e-01,  7.14806467e-01,  9.00876946e-01,  1.11286933e+00,
#         1.35236664e+00,  1.62095189e+00,  1.92020810e+00,  2.25171828e+00,
#         2.61706546e+00,  3.01783265e+00,  3.45560286e+00,  3.93195912e+00,
#         4.44848444e+00,  5.00676183e+00,  5.60837433e+00,  6.25490493e+00,
#         6.94793667e+00,  7.68905255e+00,  8.47983560e+00,  9.32186883e+00,
#         1.02167353e+01,  1.11660179e+01,  1.21712998e+01,  1.32341639e+01,
#         1.43561933e+01,  1.55389710e+01,  1.67840800e+01,  1.80931033e+01,
#         1.94676239e+01,  2.09092249e+01,  2.24194893e+01,  2.40000000e+01])

# %%
dx=x[2]-x[1]
dfdx=diff(y)/dx
xf=x[:-1]
plot(xf,dfdx)
slope_expected=12*xf**2-4*xf
plot(xf,slope_expected,'r--')

# %% [markdown]
# ## integrate with `scipy.integrate`

# %%
import scipy.integrate

# %%
y_int=scipy.integrate.cumulative_trapezoid(y,x)
plot(x[:-1],y_int)
area_expected=x**4-2*x**3/3
plot(x,area_expected,'r--')  # off by a constant

y_int=y_int-y_int[0]+area_expected[0]
plot(x[:-1],y_int,'c:')

# %% [markdown]
# ## zeros with fancy indexing

# %%
xf[:-1][sign(dfdx[:-1])!=sign(dfdx[1:])]
# Out:
# array([-0.02020202,  0.3030303 ])
