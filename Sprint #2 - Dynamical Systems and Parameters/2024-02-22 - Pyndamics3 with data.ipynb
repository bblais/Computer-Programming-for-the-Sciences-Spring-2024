# %%
# %matplotlib inline
from pylab import *
from pyndamics3 import Simulation
# Out:
# pyndamics3  version  0.0.31

# %%
import pandas as pd

# %%
data=pd.read_csv('data/sample_data.csv')
data
# Out:
#             t           y
# 0    0.000000   51.590934
# 1    2.631579   12.636075
# 2    5.263158    1.578017
# 3    7.894737  131.216052
# 4   10.526316  274.885945
# 5   13.157895  385.932344
# 6   15.789474  398.142233
# 7   18.421053  416.749192
# 8   21.052632  470.779172
# 9   23.684211  394.067240
# 10  26.315789  378.465665
# 11  28.947368  456.689517
# 12  31.578947  426.671515
# 13  34.210526  383.831704
# 14  36.842105  409.070612
# 15  39.473684  313.132069
# 16  42.105263  379.438798
# 17  44.736842  387.471958
# 18  47.368421  463.992616
# 19  50.000000  383.465799

# %%
t_data=data['t'].values
y_data=data['y'].values
t_data
# Out:
# array([ 0.        ,  2.63157895,  5.26315789,  7.89473684, 10.52631579,
#        13.15789474, 15.78947368, 18.42105263, 21.05263158, 23.68421053,
#        26.31578947, 28.94736842, 31.57894737, 34.21052632, 36.84210526,
#        39.47368421, 42.10526316, 44.73684211, 47.36842105, 50.        ])

# %%
y_data
# Out:
# array([ 51.59093439,  12.6360748 ,   1.57801714, 131.21605248,
#        274.88594474, 385.9323443 , 398.14223287, 416.74919152,
#        470.77917164, 394.06723958, 378.46566539, 456.68951672,
#        426.67151492, 383.83170408, 409.07061182, 313.13206943,
#        379.43879757, 387.47195761, 463.99261608, 383.46579904])

# %%
plot(t_data,y_data,'o')

# %%
sim=Simulation()
sim.add("y'=a*y*(1-y/K)",initial_value=2,plot=True)
sim.params(a=0.1,K=10)
sim.run(50)

# %%
sim=Simulation()
sim.add("y'=a*y*(1-y/K)",initial_value=2,plot=True)
sim.params(a=0.1,K=10)
sim.add_data(t=t_data,y=y_data,plot=True)
sim.run(50)

# %%
sim=Simulation()
sim.add("y'=a*y*(1-y/K)",initial_value=2,plot=True)
sim.params(a=1,K=400)
sim.add_data(t=t_data,y=y_data,plot=True)
sim.run(50)

# %%
sim=Simulation()
sim.add("y'=a*y*(1-y/K)",initial_value=2,plot=True)
sim.add("x'=2*a*x*(1-x/(K*1.3))",initial_value=5,plot=True)
sim.params(a=1,K=400)
sim.add_data(t=t_data,y=y_data,plot=True)
sim.run(50)

# %% [markdown]
# Quick and dirty way of plotting two simulations

# %%
sim=Simulation()
sim.add("y'=a*y*(1-y/K)",initial_value=2,plot=1)
sim.add("x'=2*a*x*(1-x/(K*1.3))",initial_value=5,plot=1)
sim.params(a=1,K=400)
sim.add_data(t=t_data,y=y_data,plot=True)
sim.run(50)

# %% [markdown]
# Better way -- turn off plot=True, and plot manually

# %%
sim=Simulation()
sim.add("y'=a*y*(1-y/K)",initial_value=2,plot=False)
sim.add("x'=2*a*x*(1-x/(K*1.3))",initial_value=5,plot=False)
sim.params(a=1,K=400)
sim.add_data(t=t_data,y=y_data,plot=True)
sim.run(50)

# %%
plot(sim.t,sim.y,'b-')
plot(t_data,y_data,'bo')
plot(sim.t,sim.x,'r-')
