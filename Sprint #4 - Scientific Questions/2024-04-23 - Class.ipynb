# %%
# %matplotlib inline
from pylab import *
from sci378 import *
# Out:
# Version:  0.0.38

# %%
y=array([.5,3,2,4.1,.7])  # this is logged data
y=10**y

t=array([0,1,2,3,4])

# %%
figure(figsize=(6,3))
plot(t,y,'-o')

# %%
figure(figsize=(6,3))
plot(t,y,'-o')
yscale('log')
